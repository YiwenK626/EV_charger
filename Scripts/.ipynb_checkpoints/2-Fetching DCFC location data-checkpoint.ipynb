# %% [markdown]
# ## Data Fetching Step 2
# This script fetches DCFC (Direct-curernt fast chargers) locations and prepares for eliminating existed chargers.
#
# 1.fetch data from NREL API
#
# 2.clean the data
#
# 3.save data as csv
#
# <i>Yiwen Wang | 04/27/2020</i>

# %%
import requests
import pandas as pd

# %%
key = open('../NRELkey.txt','r').readline()

# %%
#Request data from NREL API with a key supplied on NREL website 
baseURL = 'https://developer.nrel.gov/api/alt-fuel-stations/v1.json?'
params = {
    'api_key':key,                #key, to authenticate the service
    'status':'E',                 #E for currently available
    'fuel_type':'ELEC',           #ELEC for electricity as fuel 
    'ev_charging_level':'dc_fast',
    'state':'NC' ,                
    'limit':'all',                #set to return all the results
    'access':'public'
}
#searching parameters found on https://developer.nrel.gov/docs/transportation/alt-fuel-stations-v1/all/

# %%
#Save the request reponsese as a dictionary 
result_raw = requests.get(baseURL,params)
result_json = result_raw.json()
result_json
# Out:
# {'station_locator_url': 'http://www.afdc.energy.gov/afdc/locator/stations/',
#  'total_results': 87,
#  'station_counts': {'total': 288,
#   'fuels': {'BD': {'total': 0},
#    'E85': {'total': 0},
#    'ELEC': {'total': 288, 'stations': {'total': 87}},
#    'HY': {'total': 0},
#    'LNG': {'total': 0},
#    'CNG': {'total': 0},
#    'LPG': {'total': 0}}},
#  'fuel_stations': [{'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 40066,
#    'open_date': '2011-03-15',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Modern Nissan - Concord',
#    'station_phone': '704-788-2110',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 35.392063,
#    'longitude': -80.622777,
#    'city': 'Concord',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '967 Concord Pkwy S',
#    'zip': '28027',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 40067,
#    'open_date': '2011-03-15',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Fred Anderson Nissan',
#    'station_phone': '910-758-2338',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 35.042419,
#    'longitude': -78.956747,
#    'city': 'Fayetteville',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '4559 Raeford Rd',
#    'zip': '28304',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 43876,
#    'open_date': '2011-04-01',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Carolina Nissan',
#    'station_phone': '336-584-0201',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 36.063557,
#    'longitude': -79.503697,
#    'city': 'Burlington',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '1329 Huffman Mill Rd',
#    'zip': '27215',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 2,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 46407,
#    'open_date': '2011-08-01',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Michael Jordan Nissan',
#    'station_phone': '919-489-3800',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': 'GPS',
#    'latitude': 35.9705175060388,
#    'longitude': -78.9568475865082,
#    'city': 'Durham',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '3930 Chapel Hill Blvd',
#    'zip': '27707',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 2,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours; 704-867-0000',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-03-03',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 46998,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Gastonia Nissan',
#    'station_phone': None,
#    'updated_at': '2020-03-03T21:13:47Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': 'GPS',
#    'latitude': 35.261109,
#    'longitude': -81.139708,
#    'city': 'Gastonia',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '2755 E Franklin Blvd',
#    'zip': '28054',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours; contact 336-292-9191 for more information',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-01-13',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47003,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Crown Nissan',
#    'station_phone': None,
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': 'GPS',
#    'latitude': 36.060613,
#    'longitude': -79.876505,
#    'city': 'Greensboro',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '3900 W Wendover Ave',
#    'zip': '27407',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47005,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Greenville Nissan',
#    'station_phone': '252-756-1738',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 35.571982,
#    'longitude': -77.408327,
#    'city': 'Greenville',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '991 Greenville Blvd SW',
#    'zip': '27834',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47010,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Modern Nissan - Hickory',
#    'station_phone': '828-324-5040',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': 'GPS',
#    'latitude': 35.710136,
#    'longitude': -81.321182,
#    'city': 'Hickory',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '840 US Highway 70 SE',
#    'zip': '28602',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 2,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47032,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Ben Mynatt Nissan',
#    'station_phone': '704-633-7270',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 35.644549,
#    'longitude': -80.488272,
#    'city': 'Salisbury',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '629 Jake Alexander Blvd S',
#    'zip': '28147',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47034,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Classic Nissan - Sanford',
#    'station_phone': '919-775-2351',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 35.44411,
#    'longitude': -79.1282,
#    'city': 'Sanford',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '3305 NC Highway 87 S',
#    'zip': '27332',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47040,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Crossroads Nissan - Wake Forest',
#    'station_phone': '919-435-5700',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-8',
#    'latitude': 35.948971,
#    'longitude': -78.539171,
#    'city': 'Wake Forest',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '11120 Capital Blvd',
#    'zip': '27587',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47046,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Lee Nissan',
#    'station_phone': '252-237-4400',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': 'GPS',
#    'latitude': 35.756003,
#    'longitude': -77.9753,
#    'city': 'Wilson',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '4170 Raleigh Rd Pkwy',
#    'zip': '27896',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47048,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Modern Nissan',
#    'station_phone': '336-767-8260',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 36.179741,
#    'longitude': -80.275364,
#    'city': 'Winston-Salem',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '5795 University Pkwy',
#    'zip': '27105',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47123,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Modern Nissan - Lake Norman',
#    'station_phone': '704-237-5100',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-8',
#    'latitude': 35.467117,
#    'longitude': -80.872205,
#    'city': 'Cornelius',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '18615 Statesville Rd',
#    'zip': '28031',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 47192,
#    'open_date': '2012-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Leith Nissan',
#    'station_phone': '919-589-0029',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': 'GPS',
#    'latitude': 35.7390019,
#    'longitude': -78.8138134,
#    'city': 'Cary',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '2100 Auto Park Blvd',
#    'zip': '27511',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-09-09',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 61410,
#    'open_date': '2014-02-01',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Fred Anderson Nissan',
#    'station_phone': '919-324-3443',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': '200-9',
#    'latitude': 35.896757,
#    'longitude': -78.760671,
#    'city': 'Raleigh',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '9225 Glenwood Ave',
#    'zip': '27617',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': '9am-5pm M-F',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-11-08',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 61530,
#    'open_date': '2014-03-07',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Alphainstall.com Building',
#    'station_phone': '774-257-4246',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'OFFICE_BLDG',
#    'geocode_status': 'GPS',
#    'latitude': 35.729727,
#    'longitude': -79.176032,
#    'city': 'Pittsboro',
#    'intersection_directions': 'On Highway 15-501 and Hillsboro Street, near the intersection with Highway 64.',
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '697 Hillsboro St',
#    'zip': '27312',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': 'SOLAR',
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-10-04',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 61816,
#    'open_date': '2014-05-12',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Town of Apex - Saunders Street Parking Lot',
#    'station_phone': '919-249-3400',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'PARKING_LOT',
#    'geocode_status': 'GPS',
#    'latitude': 35.7318283,
#    'longitude': -78.8544049,
#    'city': 'Apex',
#    'intersection_directions': 'Located across the street from the Apex Police Department',
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '205 Saunders St',
#    'zip': '25702',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily; see FREEDM Reception desk for parking permit',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2019-10-04',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 64755,
#    'open_date': '2011-10-31',
#    'owner_type_code': 'SG',
#    'status_code': 'E',
#    'station_name': 'North Carolina State University - Keystone Science Center',
#    'station_phone': '919-513-3334',
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'COLLEGE_CAMPUS',
#    'geocode_status': '200-9',
#    'latitude': 35.774673,
#    'longitude': -78.677792,
#    'city': 'Raleigh',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '1791 Varsity Dr',
#    'zip': '27606',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 2,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': 'SOLAR',
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-03-03',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 76881,
#    'open_date': '2014-08-01',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Caromont Regional Medical Center',
#    'station_phone': '704-834-2000',
#    'updated_at': '2020-03-03T21:13:47Z',
#    'facility_type': 'HOSPITAL',
#    'geocode_status': 'GPS',
#    'latitude': 35.27153,
#    'longitude': -81.141587,
#    'city': 'Gastonia',
#    'intersection_directions': 'Located in the visitor parking garage',
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '2525 Court Dr',
#    'zip': '28054',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': 'Free',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': 'KEY_ALWAYS',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Card key at all times',
#    'id': 93357,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'Hyatt Place Durham Southpoint',
#    'station_phone': '877-455-3833',
#    'updated_at': '2020-04-27T10:14:29Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.900384,
#    'longitude': -78.961132,
#    'city': 'Durham',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '7840 NC Highway 751',
#    'zip': '27713',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'eVgo Network',
#    'ev_network_web': 'https://www.evgo.com/',
#    'ev_other_evse': None,
#    'ev_pricing': None,
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public - Carte-clé en tout temps',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['599'], 'posts': ['1137']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': 'KEY_ALWAYS',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Card key at all times',
#    'id': 93358,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'Courtyard Marriot',
#    'station_phone': '877-455-3833',
#    'updated_at': '2020-04-27T10:14:29Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.83511,
#    'longitude': -78.673878,
#    'city': 'Raleigh',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '3908 Arrow Dr',
#    'zip': '27612',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'eVgo Network',
#    'ev_network_web': 'https://www.evgo.com/',
#    'ev_other_evse': None,
#    'ev_pricing': None,
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public - Carte-clé en tout temps',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['598'], 'posts': ['1139']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': 'KEY_ALWAYS',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Card key at all times',
#    'id': 93359,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'Sheetz',
#    'station_phone': '877-455-3833',
#    'updated_at': '2020-04-27T10:14:29Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.855509,
#    'longitude': -78.795704,
#    'city': 'Morrisville',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '1600 Aviation Pkwy',
#    'zip': '27560',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'eVgo Network',
#    'ev_network_web': 'https://www.evgo.com/',
#    'ev_other_evse': None,
#    'ev_pricing': None,
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public - Carte-clé en tout temps',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['660'], 'posts': ['1141']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': 'KEY_ALWAYS',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Card key at all times',
#    'id': 93360,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'Sheetz',
#    'station_phone': '877-455-3833',
#    'updated_at': '2020-04-27T10:14:29Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.789742,
#    'longitude': -78.739027,
#    'city': 'Raleigh',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '600 Corporate Center Dr',
#    'zip': '27607',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'eVgo Network',
#    'ev_network_web': 'https://www.evgo.com/',
#    'ev_other_evse': None,
#    'ev_pricing': None,
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public - Carte-clé en tout temps',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['661'], 'posts': ['1143']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': 'KEY_ALWAYS',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Card key at all times',
#    'id': 93361,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'Sheetz',
#    'station_phone': '877-455-3833',
#    'updated_at': '2020-04-27T10:14:29Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.860412,
#    'longitude': -78.89456,
#    'city': 'Cary',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '4010 CONVENIENCE LN',
#    'zip': '27519',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'eVgo Network',
#    'ev_network_web': 'https://www.evgo.com/',
#    'ev_other_evse': None,
#    'ev_pricing': None,
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public - Carte-clé en tout temps',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['659'], 'posts': ['1145']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': 'KEY_ALWAYS',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Card key at all times',
#    'id': 93387,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'Asheville Outlet Mall',
#    'station_phone': '877-455-3833',
#    'updated_at': '2020-04-27T10:14:29Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.529573,
#    'longitude': -82.601858,
#    'city': 'Asheville',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '800 Brevard Rd',
#    'zip': '28806',
#    'country': 'US',
#    'bd_blends': None,
# ...
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['6457']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily; for Tesla use only',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-01-31',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 149335,
#    'open_date': '2019-09-30',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Sheetz - Tesla Supercharger',
#    'station_phone': '877-798-3752',
#    'updated_at': '2020-02-06T19:50:43Z',
#    'facility_type': None,
#    'geocode_status': '200-9',
#    'latitude': 36.458854,
#    'longitude': -80.636672,
#    'city': 'Mt Airy',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '2905 Rockford Street',
#    'zip': '27030',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['TESLA'],
#    'ev_dc_fast_num': 8,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'Tesla',
#    'ev_network_web': 'http://www.teslamotors.com/supercharger',
#    'ev_other_evse': None,
#    'ev_pricing': '$0.28 per kWh; $0.26 per minute above 60 kW and $0.13 per minute at or below 60 kW',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['8476']}},
#   {'access_code': 'public',
#    'access_days_time': 'Dealership business hours; contact 919-734-2411 for more information',
#    'access_detail_code': 'CALL',
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-01-13',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public - Call ahead',
#    'id': 149475,
#    'open_date': '2019-05-01',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Deacon Jones Nissan',
#    'station_phone': None,
#    'updated_at': '2020-01-21T18:34:38Z',
#    'facility_type': 'CAR_DEALER',
#    'geocode_status': 'GPS',
#    'latitude': 35.368612,
#    'longitude': -77.929719,
#    'city': 'Goldsboro',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '3305 McLain St',
#    'zip': '27534',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772'],
#    'ev_dc_fast_num': 1,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': 1,
#    'ev_network': 'Non-Networked',
#    'ev_network_web': None,
#    'ev_other_evse': None,
#    'ev_pricing': None,
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': "Public - Appeler à l'avance",
#    'ev_pricing_fr': None},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily; for Tesla use only',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-01-31',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 150209,
#    'open_date': '2019-11-19',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Toringdon Market - Tesla Supercharger',
#    'station_phone': '877-798-3752',
#    'updated_at': '2020-02-06T19:50:43Z',
#    'facility_type': 'SHOPPING_CENTER',
#    'geocode_status': 'GPS',
#    'latitude': 35.069256,
#    'longitude': -80.842023,
#    'city': 'Charlotte',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '3429 Toringdon Way',
#    'zip': '28277',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['TESLA'],
#    'ev_dc_fast_num': 12,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'Tesla',
#    'ev_network_web': 'http://www.teslamotors.com/supercharger',
#    'ev_other_evse': None,
#    'ev_pricing': '$0.28 per kWh; $0.26 per minute above 60 kW and $0.13 per minute at or below 60 kW',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['8818']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily; for Tesla use only',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-01-31',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 150227,
#    'open_date': '2019-11-19',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Sheetz - Tesla Supercharger',
#    'station_phone': '877-798-3752',
#    'updated_at': '2020-02-06T19:50:43Z',
#    'facility_type': 'SHOPPING_CENTER',
#    'geocode_status': 'GPS',
#    'latitude': 35.504972,
#    'longitude': -78.325441,
#    'city': 'Smithfield',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '1700 East Market Street',
#    'zip': '27577',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['TESLA'],
#    'ev_dc_fast_num': 8,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'Tesla',
#    'ev_network_web': 'http://www.teslamotors.com/supercharger',
#    'ev_other_evse': None,
#    'ev_pricing': '$0.28 per kWh; $0.26 per minute above 60 kW and $0.13 per minute at or below 60 kW',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['8461']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 152049,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'WB OFFICE 1',
#    'station_phone': '888-758-4389',
#    'updated_at': '2020-04-27T09:18:59Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 34.955772,
#    'longitude': -80.05946,
#    'city': 'Wadesboro',
#    'intersection_directions': 'PD DC 1; At Pee Dee Electric in the front parking lot. ',
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '575 US-52',
#    'zip': '28170',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 2,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'ChargePoint Network',
#    'ev_network_web': 'http://www.chargepoint.com/',
#    'ev_other_evse': None,
#    'ev_pricing': 'Pricing is based on length of time and kWh used. $0 per hour, and $20 per additional hour, $0.27 per kWh',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'posts': ['1:2038641'], 'ports': ['1']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 152884,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'BEMC',
#    'station_phone': '888-758-4389',
#    'updated_at': '2020-04-27T09:18:59Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 34.436977,
#    'longitude': -78.95024,
#    'city': 'Evergreen',
#    'intersection_directions': 'BOARDMAN; In the parking lot of the Sun-Do gas station',
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '1029 Old Boardman Rd',
#    'zip': '28438',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 2,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'ChargePoint Network',
#    'ev_network_web': 'http://www.chargepoint.com/',
#    'ev_other_evse': None,
#    'ev_pricing': '$7.5 per session',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'posts': ['1:2073651'], 'ports': ['1']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily; for Tesla use only',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-01-31',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 153454,
#    'open_date': '2020-01-31',
#    'owner_type_code': 'P',
#    'status_code': 'E',
#    'station_name': 'Parkside Town Commons - Tesla Supercharger',
#    'station_phone': '877-798-3752',
#    'updated_at': '2020-02-06T19:50:43Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.84359,
#    'longitude': -78.886368,
#    'city': 'Cary',
#    'intersection_directions': None,
#    'plus4': None,
#    'state': 'NC',
#    'street_address': "7119 O'Kelly Chapel Road",
#    'zip': '27519',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['TESLA'],
#    'ev_dc_fast_num': 12,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'Tesla',
#    'ev_network_web': 'http://www.teslamotors.com/supercharger',
#    'ev_other_evse': None,
#    'ev_pricing': '$0.28 per kWh; $0.26 per minute above 60 kW and $0.13 per minute at or below 60 kW',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'station': ['8460']}},
#   {'access_code': 'public',
#    'access_days_time': '24 hours daily',
#    'access_detail_code': None,
#    'cards_accepted': None,
#    'date_last_confirmed': '2020-04-27',
#    'expected_date': None,
#    'fuel_type_code': 'ELEC',
#    'groups_with_access_code': 'Public',
#    'id': 155154,
#    'open_date': None,
#    'owner_type_code': None,
#    'status_code': 'E',
#    'station_name': 'REVUP1',
#    'station_phone': '888-758-4389',
#    'updated_at': '2020-04-27T09:18:59Z',
#    'facility_type': None,
#    'geocode_status': 'GPS',
#    'latitude': 35.6999074,
#    'longitude': -79.787618,
#    'city': 'Asheboro',
#    'intersection_directions': 'MCDONALDS ASHBO; At the McDonald’s off of highway 64 near Randolph mall ',
#    'plus4': None,
#    'state': 'NC',
#    'street_address': '1415 E Dixie Dr',
#    'zip': '27203',
#    'country': 'US',
#    'bd_blends': None,
#    'cng_dispenser_num': None,
#    'cng_fill_type_code': None,
#    'cng_psi': None,
#    'cng_renewable_source': None,
#    'cng_total_compression': None,
#    'cng_total_storage': None,
#    'cng_vehicle_class': None,
#    'e85_blender_pump': None,
#    'e85_other_ethanol_blends': None,
#    'ev_connector_types': ['CHADEMO', 'J1772COMBO'],
#    'ev_dc_fast_num': 2,
#    'ev_level1_evse_num': None,
#    'ev_level2_evse_num': None,
#    'ev_network': 'ChargePoint Network',
#    'ev_network_web': 'http://www.chargepoint.com/',
#    'ev_other_evse': None,
#    'ev_pricing': 'Pricing is based on length of time and kWh used. $0 per hour, and $1.75 per additional hour, $0.27 per kWh',
#    'ev_renewable_source': None,
#    'hy_is_retail': None,
#    'hy_pressures': None,
#    'hy_standards': None,
#    'hy_status_link': None,
#    'lng_renewable_source': None,
#    'lng_vehicle_class': None,
#    'lpg_primary': None,
#    'lpg_nozzle_types': None,
#    'ng_fill_type_code': None,
#    'ng_psi': None,
#    'ng_vehicle_class': None,
#    'access_days_time_fr': None,
#    'intersection_directions_fr': None,
#    'bd_blends_fr': None,
#    'groups_with_access_code_fr': 'Public',
#    'ev_pricing_fr': None,
#    'ev_network_ids': {'posts': ['1:2630681'], 'ports': ['1']}}]}

# %%
#Save the fuel_stations data as a dataframe
df = pd.DataFrame.from_dict(result_json['fuel_stations'])
df.columns
# Out:
# Index(['access_code', 'access_days_time', 'access_detail_code',
#        'cards_accepted', 'date_last_confirmed', 'expected_date',
#        'fuel_type_code', 'groups_with_access_code', 'id', 'open_date',
#        'owner_type_code', 'status_code', 'station_name', 'station_phone',
#        'updated_at', 'facility_type', 'geocode_status', 'latitude',
#        'longitude', 'city', 'intersection_directions', 'plus4', 'state',
#        'street_address', 'zip', 'country', 'bd_blends', 'cng_dispenser_num',
#        'cng_fill_type_code', 'cng_psi', 'cng_renewable_source',
#        'cng_total_compression', 'cng_total_storage', 'cng_vehicle_class',
#        'e85_blender_pump', 'e85_other_ethanol_blends', 'ev_connector_types',
#        'ev_dc_fast_num', 'ev_level1_evse_num', 'ev_level2_evse_num',
#        'ev_network', 'ev_network_web', 'ev_other_evse', 'ev_pricing',
#        'ev_renewable_source', 'hy_is_retail', 'hy_pressures', 'hy_standards',
#        'hy_status_link', 'lng_renewable_source', 'lng_vehicle_class',
#        'lpg_primary', 'lpg_nozzle_types', 'ng_fill_type_code', 'ng_psi',
#        'ng_vehicle_class', 'access_days_time_fr', 'intersection_directions_fr',
#        'bd_blends_fr', 'groups_with_access_code_fr', 'ev_pricing_fr',
#        'ev_network_ids'],
#       dtype='object')

# %%
#Clean the dataframe by excluding fuel other than electricity and french results 
dropCols = [col for col in df.columns if col[:3] in ('bd_','cng','hy_','ng_','e85','lng','lpg')]
dropCols += [col for col in df.columns if col[-2:] == 'fr']
df.drop(columns = dropCols,inplace=True)
df.columns
# Out:
# Index(['access_code', 'access_days_time', 'access_detail_code',
#        'cards_accepted', 'date_last_confirmed', 'expected_date',
#        'fuel_type_code', 'groups_with_access_code', 'id', 'open_date',
#        'owner_type_code', 'status_code', 'station_name', 'station_phone',
#        'updated_at', 'facility_type', 'geocode_status', 'latitude',
#        'longitude', 'city', 'intersection_directions', 'plus4', 'state',
#        'street_address', 'zip', 'country', 'ev_connector_types',
#        'ev_dc_fast_num', 'ev_level1_evse_num', 'ev_level2_evse_num',
#        'ev_network', 'ev_network_web', 'ev_other_evse', 'ev_pricing',
#        'ev_renewable_source', 'ev_network_ids'],
#       dtype='object')

# %%
#Save the dataframe as csv file in assigned folder 
import os 
path = '/home/jovyan/work/Data/NREL'
if not os.path.exists(path):
    os.mkdir(path)
df.to_csv(path+'/DCFC.csv',index=False)
